# %% [markdown]
# <a href="https://colab.research.google.com/github/astwenjihan/2026_PraktAlPro_A_2611531003/blob/main/Laprak1_2611531003_Jihan%20Iftinan%20Syadza%20Astwen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **PRAKTIKUM ALGORITMA DAN PEMOGRAMAN**
#
# **"PENGENALAN PYTHON VS CODE DAN KONEKSI KE GITHUB"**
#
# **Disusun Oleh :**
#
# **Jihan Iftinan Syadza Astwen**
#
# **2611531003**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="https://upload.wikimedia.org/wikipedia/commons/0/01/Logo_Unand.svg?utm_source=id.wikipedia.org&utm_campaign=index&utm_content=original" width="200">
#
# <br>
#
#
#
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pertemuan 1 (Pengenalan Python, VS Code, dan koneksi ke GitHub) yang telah dilaksanakan yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemograman. Praktikum ini berfokus pada pengenalan aplikasi Python, VS Code dan juga koneksi ke GitHub.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung proses pembuatan kode program menggunakan Python di VS Code, serta mengelola repositori proyek melalui GitHub.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Python merupakan salah satu bahasa pemrograman populer yang mudah dipelajari dan banyak digunakan dalam berbagai bidang pengembangan perangkat lunak. Untuk menulis dan mengelola kodenya secara efisien, dibutuhkan lingkungan pengembangan (IDE) yang handal seperti Visual Studio Code (VS Code).
# ​Selain itu, pengelolaan dan penyimpanan kode secara aman serta terstruktur sangat diperlukan melalui sistem kontrol versi seperti GitHub. Oleh karena itu, praktikum ini penting untuk membekali mahasiswa dengan keterampilan dasar dalam menyiapkan lingkungan kerja pemrograman sekaligus melakukan manajemen kode secara profesional.
#
# ## 1.2 Tujuan
# 1. Memahami dasar-dasar bahasa pemograman dan cara menjalankan skrip program.
# 2. Mampu menggunakan Visual Studio Code (VS Code) sebagai lingkungan pengembangan (IDE) untuk Python.
# 3. Mampu melakukan inisialisasi Git serta menghubungkan proyek lokal di VS Code ke repository GitHub.
#
# ## 1.3 Manfaat
# 1. Mahasiswa dapat menguasai dasar penggunaan Python, VS Code, dan GitHub sebagai perangkat kerja standar industri dalam pengembangan perangkat lunak.
# 2. Mahasiswa mampu mengelola, menyimpan, dan mencadangkan kode program secara aman serta terstruktur menggunakan sistem kontrol versi.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Python: Bahasa pemrograman interpretatif tingkat tinggi yang berorientasi objek dan populer digunakan karena sintaksnya yang mudah dibaca serta mendukung berbagai pustaka untuk pengembangan perangkat lunak.
#
# 2. Visual Studio Code (VS Code): Source-code editor buatan Microsoft yang ringan namun kuat, dilengkapi fitur bawaan seperti debugging, manajemen ekstensi, dan integrasi terminal untuk memudahkan penulisan kode.
#
# 3. GitHub: Platform berbasis web untuk hosting dan manajemen kode sumber menggunakan sistem kontrol versi Git, yang memungkinkan pengembang berkolaborasi dan melacak perubahan kode secara daring

# %% [markdown]
# ## 2.2 Kode Program

# %% [markdown]
# **2.2.1 Program1_2611531003**

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("Hello World")
print()
print("Program ini menghasilkan")
print("Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("Program ini" + "dibuat oleh a/n"
+ "Jihan Iftinan Syadza Astwen dan NIM 2611531003.")
# Out:
# Hello World
#
# Program ini menghasilkan
# Empat baris output
# / \ // \\ /// \\\
# Program inidibuat oleh a/nJihan Iftinan Syadza Astwen dan NIM 2611531003.

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk memberikan komentar multi-baris (multi-line comment) menggunakan tanda kutip tiga ganda yang berisi informasi mengenai pertemuan pertama praktikum alpro, serta mencetak teks "Hello World" ke layar.
#
# 2. ​Bagian kedua kode ini berfungsi untuk mencetak baris kosong (print()), lalu menampilkan tiga baris teks berurutan yang menjelaskan jumlah baris output serta menampilkan pola karakter khusus berupa garis miring dan garis balik (/ \ // \\ ...).
#
# 3. ​Bagian ketiga kode ini berfungsi untuk menggabungkan dua string menggunakan operator tambah (+) guna menampilkan kalimat keterangan kepemilikan program atas nama mahasiswa.

# %% [markdown]
# **Output :**
#
#
# **Penjelasan :** Program di atas merupakan implementasi dasar bahasa Python untuk menampilkan teks ke layar menggunakan fungsi print(). Berdasarkan hasil eksekusi pada terminal, program ini berhasil mencetak teks "Hello World", informasi jumlah baris output, pola karakter khusus berupa garis miring (/ \ // \\ ...), serta identitas pembuat program (nama dan NIM) menggunakan teknik penggabungan string. Secara keseluruhan, program ini berjalan dengan lancar tanpa ada kesalahan sintaks (error).

# %% [markdown]
# ---
# ## Tugas Praktikum

# %% [markdown]
# **Tugas1_2611531003**
#
# **Soal:**
#
# 1. buatlah sebuah file program python bebas dengan nama tugas1_nim.py
# 2. buatlah laporan praktikum pekan 1 ( laporan berisi praktikum dan penjelasan tugas) dengan format file: LapPrak_ALpro1.ipyb
# 2. buatlah tahapan commit dan push file tugas dan laporan tersebut ke akun github masing-masing
# tutorial template tugas: https://drive.google.com/drive/folders/1347SclkgXMuyAvKBs_YSGFz3fpvs_qul?usp=sharing

# %% [markdown]
# **Jawaban:**

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("Hello World")
print()
print("Program ini menghasilkan")
print("Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("Program ini" + "dibuat oleh a/n"
+ "Jihan Iftinan Syadza Astwen dan NIM 2611531003.")
# Out:
# Hello World
#
# Program ini menghasilkan
# Empat baris output
# / \ // \\ /// \\\
# Program inidibuat oleh a/nJihan Iftinan Syadza Astwen dan NIM 2611531003.

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk memberikan komentar multi-baris (multi-line comment) menggunakan tanda kutip tiga ganda yang berisi informasi mengenai pertemuan pertama praktikum alpro, serta mencetak teks "Hello World" ke layar.
#
# 2. ​Bagian kedua kode ini berfungsi untuk mencetak baris kosong (print()), lalu menampilkan tiga baris teks berurutan yang menjelaskan jumlah baris output serta menampilkan pola karakter khusus berupa garis miring dan garis balik (/ \ // \\ ...).
#
# 3. ​Bagian ketiga kode ini berfungsi untuk menggabungkan dua string menggunakan operator tambah (+) guna menampilkan kalimat keterangan kepemilikan program atas nama mahasiswa.

# %% [markdown]
# **Output :**
#
#
# **Penjelasan :** Program di atas merupakan implementasi dasar bahasa Python untuk menampilkan teks ke layar menggunakan fungsi print(). Berdasarkan hasil eksekusi pada terminal, program ini berhasil mencetak teks "Hello World", informasi jumlah baris output, pola karakter khusus berupa garis miring (/ \ // \\ ...), serta identitas pembuat program (nama dan NIM) menggunakan teknik penggabungan string. Secara keseluruhan, program ini berjalan dengan lancar tanpa ada kesalahan sintaks (error).

# %% [markdown]
# **2.2.2 Tugas1_2611531003**

# %%
print("Hello World! This is me")
print("My name is Jihan")
print(" ========")
print("|  o   o |")
print("|    A   |")
print(" ========")
# Out:
# Hello World! This is me
# My name is Jihan
# ...
# |  o   o |
# |    A   |
# ...

# %% [markdown]
# **Penjelasan:**
#
# 1. print("Hello World! This is me") Mencetak kalimat sapaan dan perkenalan singkat ke layar.
#
# 2. print("My name is Jihan") Mencetak informasi nama pemilik pesan, yaitu Jihan.
#
# 3. print(" ========") Mencetak garis atas dari bingkai atau kotak hiasan menggunakan karakter spasi dan tanda sama dengan (=).
#
# 4. print("| o o |") Mencetak baris pertama bagian dalam kotak yang berisi dua huruf "o", berfungsi sebagai simbol mata.
#
# 5. print("| A |") Mencetak baris kedua bagian dalam kotak yang berisi huruf "A", berfungsi sebagai simbol hidung.
#
# 6. print(" ========") Mencetak garis bawah untuk menutup bingkai kotak sehingga membentuk ilustrasi wajah sederhana.
#
#
# **Output:**
#
# Penjelasan : Program di atas merupakan implementasi dasar bahasa Python untuk menampilkan teks dan karakter khusus menggunakan fungsi print(). Berdasarkan hasil eksekusi pada terminal, program ini berhasil mencetak kalimat perkenalan diri, serta ilustrasi wajah ASCII art secara rapi. Secara keseluruhan, program ini berjalan dengan lancar tanpa ada kesalahan sintaks (error).

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa mahasiswa telah berhasil memahami dasar-dasar penggunaan Python, mengonfigurasi perangkat pengembangan menggunakan Visual Studio Code (VS Code), serta menghubungkan proyek lokal ke platform pengelolaan kode GitHub.
#
# ​Dalam konteks pemrograman modern, konsep ini memanfaatkan lingkungan kerja terintegrasi dan sistem kontrol versi sehingga pengembang dapat menulis, mengelola, mencadangkan, serta berkolaborasi dalam pembuatan kode sumber secara aman, terstruktur, dan efisien.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# ​[1] G. Van Rossum and F. L. Drake, Python 3 Reference Manual, CreateSpace, 2009.
# ​[2] Microsoft, "Visual Studio Code Documentation - Getting Started with Python in VS Code," 2023. [Online]. Tersedia: https://code.visualstudio.com/docs/python/python-tutorial. [Diakses tanggal: 5 September 2026].
# ​[3] S. Chacon and B. Straub, Pro Git, Apress, 2014.
