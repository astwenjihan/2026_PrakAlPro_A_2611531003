# %% [markdown]
# <a href="https://colab.research.google.com/github/astwenjihan/2026_PrakAlPro_A_2611531003/blob/main/Laprak2_2611531003_Jihan_Iftinan_Syadza_Astwen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **PRAKTIKUM ALGORITMA DAN PEMOGRAMAN**
#
# **"TIPE DATA DAN VARIABEL"**
#
# **Disusun Oleh :**
#
# **Jihan Iftinan Syadza Astwen**
#
# **2611531003**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="https://upload.wikimedia.org/wikipedia/commons/0/01/Logo_Unand.svg?utm_source=id.wikipedia.org&utm_campaign=index&utm_content=original" width="200">
#
# <br>
#
#
#
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pertemuan 2 (Tipe Data dan Variabel) yang telah dilaksanakan yang telah dilaksanakan sebagai pertemuan ke-2 untuk mata kuliah Praktikum Algoritma dan Pemograman. Praktikum ini berfokus pada pengenalan tipe data dan variabel
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung penggunaan berbagai macam tipe data dan variabel ke dalam kode program yang interaktif.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pemrograman komputer merupakan salah satu kemampuan dasar yang sangat penting untuk dikuasai dalam era digital saat ini. Salah satu konsep fundamental yang wajib dipahami sebelum mempelajari algoritma yang lebih kompleks adalah konsep variabel dan tipe data. Variabel berfungsi sebagai wadah untuk menyimpan suatu nilai yang dapat digunakan dan diproses selama program dijalankan, sedangkan tipe data menentukan jenis nilai yang dapat disimpan dalam variabel tersebut, seperti angka (numerik), teks(string), nilai benar/salah(boolean), nama input maupun nilai tetap(konstanta).
#
# Bahasa pemrograman Python dipilih dalam praktikum ini karena memiliki sintaks yang sederhana, mudah dipahami oleh pemula, serta bersifat dynamically typed, artinya tipe data suatu variabel ditentukan secara otomatis oleh Python berdasarkan nilai yang diberikan tanpa perlu dideklarasikan secara eksplisit seperti pada bahasa pemrograman lain. Meskipun demikian, pemahaman yang mendalam mengenai tipe data tetap diperlukan agar program yang dibuat dapat berjalan dengan benar dan efisien.
#
# Melalui praktikum ini, mahasiswa diajak untuk mempraktikkan langsung penggunaan berbagai tipe data, yaitu string untuk menyimpan data biodata diri, boolean untuk menentukan status kelulusan, numerik (integer, float, dan complex) untuk melakukan perhitungan matematis, serta konstanta yang nilainya tidak dapat diubah selama program berjalan, seperti nilai PI dalam perhitungan luas lingkaran.
# ​
#
# ## 1.2 Tujuan
# 1. Memahami konsep dasar variabel dan berbagai jenis tipe data dalam bahasa pemrograman Python.
#
# 2. Mampu mengimplementasikan tipe data numerik, string, boolean, input dari pengguna, serta konstanta ke dalam bentuk kode program.
#
# 3. Mempraktikkan cara kerja Python yang bersifat dynamically typed dalam mengenali jenis data pada suatu variabel.
#
# ## 1.3 Manfaat
# 1. Memberikan pemahaman praktis bagi mahasiswa dalam mendeklarasikan, mengelola, dan memanipulasi variabel serta tipe data secara tepat.
# 2. Melatih kemampuan logika berpikir komputasi untuk menyelesaikan masalah pemrograman dasar.
# 3. ​Membangun fondasi yang kuat bagi mahasiswa sebelum mempelajari struktur data dan algoritma yang lebih kompleks di pertemuan selanjutnya.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Konsep Variabel: Wadah atau lokasi di memori komputer yang digunakan untuk menyimpan nilai data. Di Python, variabel tidak perlu dideklarasikan dengan tipe data tertentu secara eksplisit karena Python menganut sistem dynamically typed.
# ​
# 2. Tipe Data Numerik: Digunakan untuk menyimpan data angka. Terdiri dari Integer (int) untuk bilangan bulat, Float (float) untuk bilangan desimal, dan Complex (complex) untuk bilangan berjenis imajiner.
#
# 3. Tipe Data String (str): Digunakan untuk merepresentasikan teks atau kumpulan karakter yang diapit oleh tanda kutip tunggal, ganda, maupun tiga tanda kutip (""") untuk teks multi-baris.
# 4. Tipe Data Boolean (bool): Tipe data yang hanya memiliki dua nilai kebenaran mutlak, yaitu True (benar) dan False (salah), yang biasanya dihasilkan dari operasi perbandingan logika.
#
# 5. Input dari Pengguna (input()): Fungsi bawaan yang digunakan untuk menerima masukan data dari pengguna melalui terminal/konsol, di mana nilai yang diterima secara default bertipe data string dan dapat dikonversi (casting) ke bentuk lain.
#
# 6. Konstanta: Variabel yang nilainya bersifat tetap dan tidak boleh diubah sepanjang eksekusi program. Dalam konvensi bahasa Python, penamaan konstanta ditulis menggunakan huruf kapital seluruhnya.

# %% [markdown]
# ## 2.2 Kode Program

# %% [markdown]
# ## 2.2.1 Numerik_2611531003.py

# %%
#create a variable with integer value
a_1003=100
print("The type of variable having value", a_1003, "is", type(a_1003))

#create a variable with float value
b_1003=10.2345
print("The type of variable having value", b_1003, "is", type(b_1003))

#create a variable with complex value
c_1003=100+3j
print("The type of variable having value", c_1003, "is", type(c_1003))
# Out:
# The type of variable having value 100 is <class 'int'>
# The type of variable having value 10.2345 is <class 'float'>
# The type of variable having value (100+3j) is <class 'complex'>

# %% [markdown]
# **Penjelasan Kode:**
#
# 1. Variabel Integer (a_1003)
# Kode: a_1003 = 100 lalu print(..., type(a_1003))
# Penjelasan: Baris ini membuat variabel bernama a_1003 dan mengisinya dengan nilai bilangan bulat. Di Python, angka tanpa titik desimal otomatis dikategorikan sebagai tipe data int (integer). Fungsi type() akan mengembalikan keterangan <class 'int'>.
#
#
# 2. Variabel Float (b_1003)
# Kode: b_1003 = 10.2345 lalu print(..., type(b_1003))
# Penjelasan: Baris ini mendefinisikan variabel dengan nilai pecahan atau desimal. Nilai yang mengandung tanda titik akan otomatis terbaca oleh Python sebagai tipe data float (bilangan desimal). Fungsi type() mendeteksinya sebagai <class 'float'>.
#
#
# 3. Variabel Complex (c_1003)
# Kode: c_1003 = 100 + 3j lalu print(..., type(c_1003))
# Penjelasan: Baris ini mendeklarasikan bilangan kompleks yang terdiri dari bagian riil (100) dan bagian imajiner (3j, di mana huruf j mendefinisikan unit imajiner dalam matematika). Python mendukung tipe data ini secara langsung dan mengembalikannya sebagai <class 'complex'>.
#
# 4. Fungsi Utama yang Digunakan
# type(): Fungsi bawaan Python (built-in function) untuk mendeteksi dan menampilkan jenis tipe data dari suatu variabel secara dinamis.
# print(): Berfungsi untuk menampilkan teks, nilai variabel, serta hasil dari fungsi type() secara bersamaan ke layar terminal agar mudah dibaca.
#
#
# **Penjelasan Output:**
#
# 1.  a_1003 = 100: Menyimpan data angka bulat (int).
# ​
# 2. b_1003 = 10.2345: Menyimpan data angka desimal (float).
#
# 3. ​c_1003 = 100 + 3j: Menyimpan dat
# a angka imajiner/kompleks (complex).
#
#
# 4. type(): Fungsi bawaan Python untuk mengecek jenis tipe data variabel yang dicetak.

# %% [markdown]
# ## 2.2.2 String_2611531003.py

# %%
# Buat file dengan nama String_NIM.py
#nama variabel ditambah 4 digit nim terakhir contoh: nama_1234
#ganti programnya dengan data masing masing
nama_1003 = "Jihan"
jenis_kelamin_1003 = "Perempuan"
alamat_1003 = """
Jl. Bariang Cubadak Raya
Kec. Kuranji
Kota Padang
"""
agama_1003 = "Islam"
print("Nama saya adalah", nama_1003)
print("Jenis kelamin saya adalah", jenis_kelamin_1003)
print("Alamat saya adalah", alamat_1003)
print("Agama saya adalah", agama_1003)
# Out:
# Nama saya adalah Jihan
# Jenis kelamin saya adalah Perempuan
# Alamat saya adalah
# Jl. Bariang Cubadak Raya
# Kec. Kuranji
# Kota Padang
#
# Agama saya adalah Islam

# %% [markdown]
# **Penjelasan Kode:**
#
# 1. Variabel String (nama_1003, jenis_kelamin_1003, agama_1003): Menyimpan teks singkat menggunakan tanda kutip satu atau dua ("...").
#
# 2. ​Multi-line String (alamat_1003): Menggunakan tiga tanda kutip ("""...""") untuk menyimpan teks panjang atau lebih dari satu baris secara rapi.
#
# 3. Fungsi print(): Menampilkan teks keterangan beserta isi variabel ke layar terminal.
#
#
#
# **Penjelasan Output:**
#
# Program akan mencetak informasi identitas diri secara berurutan mulai dari nama, jenis kelamin, alamat yang terdiri dari beberapa baris, hingga agama berdasarkan data variabel yang telah diisi.

# %% [markdown]
# ## 2.2.3 Boolean_2611531003.py

# %%
# Buat file dengan nama Boolean_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: nama_1234
# Deklarasi variabel dengan tipe data Boolean
is_lulus_1003 = True
is_cumlaude_1003 = True

# Menggunakan Boolean
nilai_1003 = 85
batas_lulus_1003 = 75

# Menentukan nilai Boolean dari kondisi
status_kelulusan_1003 = nilai_1003 >= batas_lulus_1003 # Hasilnya akan True

print("=== Check Kelulusan ===")
print("Nilai:", nilai_1003)
print("Apakah lulus?", status_kelulusan_1003)
if is_lulus_1003 and is_cumlaude_1003:
    print("Selamat, Anda lulus dengan predikat Cumlaude!")

# %% [markdown]
# **Penjelasan Kode:**
# ​
#
# 1. Tipe Data Boolean (is_lulus_1003, is_cumlaude_1003): Menyimpan nilai kebenaran murni, yaitu True (benar) atau False (salah).
#
#
# 2. Operator Perbandingan (>=): Membandingkan angka 85 dan 75 untuk menghasilkan nilai boolean secara otomatis ke dalam variabel status_kelulusan_1003.
# ​
#
# 3. Operator Logika (and): Menggabungkan dua kondisi boolean di dalam struktur percabangan if agar pesan cumlaude hanya tampil jika kedua variabel bernilai True.
#
#
#
#
# **​Penjelasan Output:**
#
#
# ​Menampilkan judul pemeriksaan kelul
# usan, mencetak nilai angka, menampilkan status kelulusan berupa nilai True, serta mengeksekusi blok if untuk mencetak kalimat "Selamat, Anda lulus dengan predikat Cumlaude!" ke layar karena seluruh syarat bernilai benar.

# %% [markdown]
# ## 2.2.4 Input_2611531003.py

# %%
# Buat file dengan nama Input_NIM.py
# Buat program untuk menghitung luas persegi panjang
# Nama variabel ditambah 4 digit nim terakhir contoh: panjang_1234
# Program ini menggunakan fungsi input() untuk meminta pengguna
# memasukkan nilai panjang dan lebar persegi panjang.
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
panjang_1003 = input("Masukkan nilai panjang: ")
lebar_1003 = input("Masukkan nilai lebar: ")
luas_1003 = int(panjang_1003) * int(lebar_1003)
print("Luas =", luas_1003)

# %% [markdown]
# **Penjelasan Kode:**
#
# 1. ​Fungsi input() (panjang_1003, lebar_1003): Digunakan untuk menerima masukan data dari pengguna melalui terminal/konsol. Apapun yang diketik pengguna lewat fungsi ini akan otomatis dibaca sebagai tipe data string.
#
# 2. ​Konversi Tipe Data / Casting (int(...)): Mengubah nilai string dari input pengguna menjadi bilangan bulat (integer) agar bisa dioperasikan secara aritmatika, karena data teks murni tidak bisa dikalikan secara matematis.
#
# 3. Operasi Perkalian: Mengalikan variabel panjang dan lebar yang sudah dikonversi untuk mendapatkan hasil luas persegi panjang.
#
# 4. Fungsi print(): Berfungsi untuk mencetak teks keterangan beserta hasil akhir perhitungan ke layar terminal.
#
#
# **Penjelasan Output:**
#
# Program akan meminta pengguna memasukkan nilai panjang dan lebar secara berurutan. Jika pengguna memasukkan angka 10 untuk panjang dan 5 untuk lebar, program akan memproses perkaliannya dan mencetak teks Luas = 50 ke layar.

# %% [markdown]
# ## 2.2.5 Konstanta_2611531003.py

# %%
# Buat file dengan nama Konstanta_NIM.py
# Program ini menggunakan konstanta untuk menghitung luas lingkaran
# Nama variabel ditambah 4 digit nim terakhir contoh: jari_1234

from typing import Final
PI: Final = 3.14
print("pi: %f" % (PI))
jari_1003 = float(input("Masukkan nilai jari-jari: "))
luas_1003 = PI * jari_1003 * jari_1003
print("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_1003, luas_1003))

# %% [markdown]
# **Penjelasan Kode:**
#
# 1. ​from typing import Final & PI: Final = 3.14: Menggunakan modul Final untuk menandai variabel PI sebagai konstanta (nilai tetap) dengan penulisan huruf kapital sesuai konvensi umum pemrograman.
#
# 2. ​float(input(...)): Menerima masukan dari pengguna via terminal dan langsung mengonversinya menjadi bilangan desimal (float) agar siap dihitung secara matematis.
#
# 3. Perhitungan Luas (luas_1003 = PI * jari_1003 * jari_1003): Mengalikan nilai konstanta PI dengan kuadrat jari-jari dari input pengguna.
#
# 4.  Format String (%f & %.2f): Mengatur tampilan angka desimal agar tercetak rapi dengan batasan dua angka di belakang koma.
#
#
# **​Penjelasan Output:**
# Program akan menampilkan nilai PI, lalu meminta pengguna memasukkan angka jari-jari (contoh: 7). Setelah itu, program akan memproses rumus dan mencetak hasil akhirnya secara rapi, misalnya: “Luas lingkaran dengan jari-jari 7.00 adalah 153.86”.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal:**
#
# Studi Kasus: Sistem Biodata dan Validasi
# Kelulusan Praktikan
# Anda diminta untuk merancang sebuah program konsol sederhana yang mencatat data
# identitas praktikan baru dan melakukan verifikasi status kelulusan awal praktikum secara
# otomatis. Seluruh elemen materi Pekan 2 wajib diintegrasikan dalam satu alur program yang
# utuh.
# Ketentuan Teknis Program
# 1. Aturan Penamaan Variabel: Setiap variabel yang dibuat wajib diakhiri dengan 4 digit
# terakhir NIM mahasiswa (contoh untuk NIM akhiran 1234: nama_1234, umur_1234,
# nilai_1234). Penulisan variabel harus mematuhi kaidah case-sensitive dan tidak boleh
# menggunakan kata kunci bawaan Python (reserved keywords).
#
# 2. Penerapan Konstanta: Buat ketetapan batas kelulusan (misalnya skor 75.0)
# menggunakan modul typing.Final. Konstanta dideklarasikan di awal program dengan
# format penulisan huruf kapital.
#
# 3. Tipe Data String & Char:
#
# ○ Ambil data nama praktikan menggunakan fungsi input().
#
# ○ Gunakan tanda petik tunggal atau ganda untuk karakter inisial / jenis kelamin.
#
# ○ Gunakan tanda petik tiga ("""...""") untuk menyimpan alamat tempat tinggal secara
# multiline (lebih dari satu baris).
#
# 4. Tipe Data Numerik & Type Casting:
#
# ○ Gunakan fungsi input() yang dikonversi ke tipe data Integer (int()) untuk masukan
# umur atau semester.
#
# ○ Gunakan fungsi input() yang dikonversi ke tipe data Float (float()) untuk masukan
# nilai ujian / skor tes awal praktikum.
#
# ○ Deklarasikan satu variabel bilangan kompleks (Complex) sebagai token identifikasi
# praktikan (contoh: 100 + 3j).
#
# 5. Tipe Data Boolean: Evaluasi status kelulusan praktikan secara dinamis menggunakan
# operator logika perbandingan (misalnya: nilai_1234 >= BATAS_LULUS) sehingga
# menghasilkan nilai True atau False.
#
# 6. Pengecekan Tipe Data (type()): Program wajib menampilkan semua data yang telah
# diinput dan diproses ke layar, disertai dengan tipe datanya masing-masing menggunakan
# fungsi bawaan type().

# %% [markdown]
# **Jawaban:**

# %%
# 1. Konstanta Batas Kelulusan
# Nama variabel ditambah 4 digit nim terakhir contoh: a_1234
Batas_Lulus_1003 = 75.0

print("=== SISTEM REGISTRASI PRAKTIKAN ALPRO 2026 ===")

# 2. Input Data (String & Numerik)
nama_1003 = input("Masukkan Nama Mahasiswa : ")
jk_1003 = input("Masukkan Jenis Kelamin (L/P): ")

# Alamat menggunakan petik tiga (multiline) sesuai ketentuan tugas
alamat_1003 = """Jl. Kampus Unand,
Kecamatan Pauh,
Kota Padang"""

umur_1003 = int(input("Masukkan Umur : "))
nilai_1003 = float(input("Masukkan Skor Tes Awal : "))

# Variabel bilangan kompleks untuk token (tipe data complex)
token_1003 = 100 + 3j

# 3. Evaluasi Boolean (Status Kelulusan)
status_lulus_1003 = nilai_1003 >= Batas_Lulus_1003

# 4. Output dan Pengecekan Tipe Data dengan type()
print("\n=== DATA PRAKTIKAN & HASIL PEMERIKSAAN ===")
print(f"Nama Mahasiswa : {nama_1003} | Tipe: {type(nama_1003)}")
print(f"Jenis Kelamin : {jk_1003} | Tipe: {type(jk_1003)}")
print(f"Alamat Domisili:\n{alamat_1003} | Tipe: {type(alamat_1003)}")
print(f"Umur : {umur_1003} tahun | Tipe: {type(umur_1003)}")
print(f"Skor Tes Awal : {nilai_1003} | Tipe: {type(nilai_1003)}")
print(f"ID Token Sinyal: {token_1003} | Tipe: {type(token_1003)}")

print("\n=== STATUS KELULUSAN PRAKTIKUM ===")
print(f"Batas Minimum Nilai: {Batas_Lulus_1003}")
print(f"Apakah Dinyatakan Lulus?: {status_lulus_1003} | Tipe: {type(status_lulus_1003)}")
# Out:
# === SISTEM REGISTRASI PRAKTIKAN ALPRO 2026 ===
#
# === DATA PRAKTIKAN & HASIL PEMERIKSAAN ===
# Nama Mahasiswa : ji | Tipe: <class 'str'>
# Jenis Kelamin : p | Tipe: <class 'str'>
# Alamat Domisili:
# Jl. Kampus Unand,
# Kecamatan Pauh,
# Kota Padang | Tipe: <class 'str'>
# Umur : 18 tahun | Tipe: <class 'int'>
# Skor Tes Awal : 95.0 | Tipe: <class 'float'>
# ID Token Sinyal: (100+3j) | Tipe: <class 'complex'>
#
# === STATUS KELULUSAN PRAKTIKUM ===
# Batas Minimum Nilai: 75.0
# Apakah Dinyatakan Lulus?: True | Tipe: <class 'bool'>

# %% [markdown]
# **Penjelasan:**
#
# 1. Batas_Lulus_1003 = 75.0 Mendeklarasikan konstanta batas minimum nilai kelulusan praktikum sebesar 75.0.
#
# 2. ​print("=== SISTEM REGISTRASI PRAKTIKAN ALPRO 2026 ===")ing Mencetak judul utama sistem registrasi ke layar konsol.
#
# 3. ​nama_1003 = input("...") Mengambil masukan nama mahasiswa dari pengguna dan menyimpannya ke dalam variabel bertipe data string.
# ​
# 4. jk_1003 = input("...") Mengambil masukan jenis kelamin praktikan dari pengguna.
# ​
# 5. alamat_1003 = """...""" Menyimpan data alamat domisili praktikan secara multiline (lebih dari satu baris) menggunakan tanda petik tiga.
#
# 6. ​umur_1003 = int(input("...")) Mengambil masukan umur dan mengubah tipe datanya dari string menjadi integer menggunakan fungsi int().
#
# 7. ​nilai_1003 = float(input("...")) Mengambil masukan skor tes awal dan mengubah tipe datanya menjadi float menggunakan fungsi float().
#
# 8. ​token_1003 = 100 + 3j Mendeklarasikan variabel bilangan kompleks sebagai token identifikasi khusus praktikan.
# ​
# 9. status_lulus_1003 = nilai_1003 >= Batas_Lulus_1003 Mengevaluasi status kelulusan secara dinamis menggunakan operator perbandingan sehingga menghasilkan nilai boolean (True atau False).
# ​
# 10. print(...) dan type(...) Menampilkan seluruh data yang telah diinput dan diproses ke layar konsol beserta informasi tipe data masing-masing menggunakan fungsi bawaan type().
#
# **Output**
#
# ​Penjelasan: Program di atas merupakan implementasi bahasa Python untuk sistem registrasi dan validasi kelulusan praktikan yang mengintegrasikan berbagai tipe data, konstanta, type casting, serta operator perbandingan. Berdasarkan hasil eksekusi pada terminal, program ini berhasil mencetak seluruh data identitas, menampilkan struktur alamat multiline, serta melakukan pengecekan tipe data menggunakan fungsi type() secara akurat. Variabel status kelulusan menghasilkan nilai True karena skor tes awal praktikan (82.5) memenuhi syarat lebih besar atau sama dengan batas minimum kelulusan (75.0). Keseluruhan program berjalan dengan lancar tanpa ada kesalahan sintaks (error).

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, Kesimpulan dari praktikum ini adamemahami dan mengimplementasikan konsep dasar variabel serta berbagai tipe data di Python, yang meliputi numerik (integer, float, complex), string, dan boolean. Selain itu, praktikum ini juga melatih penggunaan input dari pengguna secara interaktif dengan teknik casting, serta penerapan konstanta menggunakan modul Final agar nilai data tertentu tetap terjaga dan tidak berubah selama program berjalan.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# ​[1] Lutz, M. (2013). Learning Python (5th ed.). O'Reilly Media.
# ​
#
# [2] Matthes, E. (2019). Python Crash Course: A Hands-On, Project-Based Introduction to Programming (2nd ed.). No Starch Press.
# ​
#
# [3] Python Software Foundation. (2026). Built-in Types — Python Documentation. Diakses dari https://docs.python.org/3/library/stdtypes.html
